# %%
# Configurações iniciais
import pandas as pd
import pyautogui as ptg
from time import sleep
df = pd.read_excel('sheet_ops.xlsx')

# %%
# Play na automação
for i, material in enumerate(df['MATERIAL']):
    pallets = str(df.loc[i, "yyyPALLET"])
    op = str(df.loc[i, "yyyOP"])
    sku = str(df.loc[i, "yyySKU"])
    peso = str(df.loc[i, "yyyPESO"])
    c1 = str(df.loc[i, "yyyC1"])
    c2 = str(df.loc[i, "yyyC2"])
    c3 = str(df.loc[i, "yyyC3"])
    
    ptg.hotkey('win','r')
    sleep(0.5)
    ptg.typewrite('C:\\Users\\iesus.candido_petfiv\\Desktop\\GitHub\\PO_Press\\model.docx')
    ptg.press('enter')
    
    sleep(3)
    ptg.press('right')
    ptg.press('right')
    ptg.typewrite(op)
    
    sleep(0.3)    
    ptg.press('down')
    ptg.typewrite(sku)
    
    sleep(0.3)    
    ptg.press('enter')
    ptg.typewrite(peso)

    sleep(0.3)    
    ptg.press('down')
    ptg.press('left')
    ptg.press('alt')
    sleep(0.3)
    ptg.press('n')
    sleep(0.3)
    ptg.press('s')
    sleep(0.3)
    ptg.press('x')
    sleep(0.3)
    ptg.typewrite('nov')
    ptg.press('down')
    sleep(0.3)
    ptg.press('enter')
    sleep(0.5)
    ptg.press('enter')

    sleep(0.3)    
    ptg.press('alt')
    sleep(0.3)
    ptg.press('n')
    sleep(0.3)
    ptg.press('f')
    sleep(0.3)
    ptg.press('enter')
    sleep(0.3)
    ptg.press('right')
    sleep(0.2)
    ptg.typewrite(pallets)
    
    sleep(0.3)
    ptg.hotkey('ctrl','end')
    sleep(0.3)
    ptg.press('up')
    sleep(0.1)
    ptg.press('up')
    sleep(0.1)
    ptg.press('up')
    sleep(0.1)
    ptg.press('up')
    
    sleep(0.3)
    ptg.typewrite(c1)
    sleep(0.3)
    ptg.press('right')

    sleep(0.3)
    ptg.typewrite(c2)
    sleep(0.3)
    ptg.press('right')
    
    sleep(0.3)
    ptg.typewrite(c3)
    sleep(0.3)
    ptg.press('right')
    sleep(0.5)
    
    ptg.press('alt')
    sleep(0.3)
    ptg.press('n')
    sleep(0.3)
    ptg.press('o')
    sleep(0.3)
    ptg.press('i')
    sleep(0.3)
    ptg.press('down')
    ptg.press('down')
    ptg.press('1')
    sleep(0.3)
    ptg.press('tab')
    ptg.typewrite(pallets)



    sleep(0.5)
    ptg.press('enter')
    sleep(1)
    ptg.press('enter')
    sleep(1)

    ptg.press('alt')
    sleep(0.5)
    ptg.press('a')
    sleep(0.5)
    ptg.press('c')
    sleep(0.5)
    ptg.press('n')
    sleep(1)

ptg.alert('PO_Press: Automação concluída com sucesso!')
# Out:
# 'OK'
